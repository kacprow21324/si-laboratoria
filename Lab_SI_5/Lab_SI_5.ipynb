# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional, Input
from keras.optimizers import SGD, Adam
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from keras.losses import Huber

# %%
# Funkcje pomocnicze: wykres predykcji modelu, metryki oceny modelu RMSE i MAE)
# Jeśli RMSE jest dużo wyższe niż MAE, oznacza to, że model radzi sobie dobrze przez większość czasu,
# ale "wywala się" na kilku konkretnych dniach (np. przy nagłych krachach giełdowych).

def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
    plt.show()

# RMSE – Pierwiastek błędu średniokwadratowego (Root Mean Squared Error) -
# przed uśrednieniem podnosi błędy do kwadratu, przez co duże błędy są karane
# nieproporcjonalnie mocno. Jeden bardzo zły wynik potrafi znacząco podnieść RMSE,
# podczas gdy MAE ledwo drgnie.

def return_rmse(test, predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("-" * 30)
    print("Błąd średniokwadratowy modelu {:.2f}.".format(rmse))
    print("-" * 30)

# MAE – Średni błąd bezwzględny (Mean Absolute Error) - liczy średnią z wartości
# bezwzględnych błędów. Każdy błąd waży tyle samo,
# niezależnie od tego czy jest duży czy mały.

def return_mae(test, predicted):
    mae = mean_absolute_error(test, predicted)
    mape = mean_absolute_percentage_error(test, predicted) * 100
    print("Średni błąd bezwzględny: {:.2f}.".format(mae))
    print("Średni błąd bezwzględny procentowy: {:.2f}%".format(mape))
    print("-" * 30)

# !! Jeśli duże błędy są szczególnie kosztowne → patrz na RMSE
# !! Jeśli wszystkie błędy są równie ważne → patrz na MAE
# !! Jeśli chcesz wynik niezależny od skali danych (np. porównujesz różne produkty) → MAPE

# %%
dataset = pd.read_csv('IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
# Ustawiamy zbiory trenujące i testowe oraz szukamy brakujących wartości
training_set = dataset[:'2016'].iloc[:,1:2].values
test_set = dataset['2017':].iloc[:,1:2].values

# %%
# Wizualizacja danych
dataset["High"][:'2016'].plot(figsize=(16,4),legend=True)
dataset["High"]['2017':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2017)','Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
# Normalizacja danych trenujących
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Ponieważ komórki LSTM przechowują stan pamięci długotrwałej,
# tworzymy strukturę danych z 60 krokami czasowymi i 1 wyjściem
# Zatem dla każdego elementu zestawu treningowego mamy 60 poprzednich elementów zestawu treningowego.
X_train = []
y_train = []
for i in range(60,2769):
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Przekształcanie X_train w celu zapewnienia wydajnego modelowania
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
# Architektura LSTM, sieć regresyjna, predykująca
regressor = Sequential()
# Warstwa wejściowa
regressor.add(Input(shape=(X_train.shape[1], 1)))
# Pierwsza warstwa LSTM
regressor.add(LSTM(units=500, return_sequences=True))
regressor.add(Dropout(0.2))
# Druga warstwa LSTM z regularyzacją Dropout
regressor.add(LSTM(units=500, return_sequences=True))
regressor.add(Dropout(0.2))
# Trzecia warstwa LSTM z regularyzacją Dropout
regressor.add(LSTM(units=500, return_sequences=True))
regressor.add(Dropout(0.2))
# Czwarta warstwa LSTM z regularyzacją Dropout
regressor.add(LSTM(units=500))
regressor.add(Dropout(0.2))
# Warstwa wyjściowa
regressor.add(Dense(units=1))

# Ustawiamy funkcję optymalizującą wagi (uczącą) i funkcję straty
regressor.compile(optimizer='rmsprop',loss='mean_squared_error')

# Trenujemy sieć, ustawiamy ilość epok i ilość podawanych próbek ze zbioru trenującego
regressor.fit(X_train,y_train,epochs=50,batch_size=32)

# Wersja treningu z mechanizmem Early Stopping zapobiegającym przeuczeniu się sieci
# (zakomentować powyższe, odkomentować poniższe)
#early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
#regressor.fit(X_train, y_train, epochs=100, batch_size=32, callbacks=[early_stop])
# Out:
# Epoch 1/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 0.1580
# Epoch 2/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0192
# Epoch 3/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0072
# Epoch 4/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0051
# Epoch 5/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0042
# Epoch 6/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0035
# Epoch 7/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0030
# Epoch 8/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0029
# Epoch 9/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0026
# Epoch 10/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0026
# Epoch 11/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0022
# Epoch 12/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0023
# Epoch 13/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0022
# Epoch 14/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0021
# Epoch 15/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0019
# Epoch 16/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0020
# Epoch 17/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0018
# Epoch 18/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0019
# Epoch 19/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0018
# Epoch 20/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0016
# Epoch 21/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0016
# Epoch 22/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0017
# Epoch 23/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0016
# Epoch 24/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0015
# Epoch 25/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0016
# Epoch 26/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0015
# Epoch 27/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0015
# Epoch 28/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0014
# Epoch 29/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0014
# Epoch 30/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0014
# Epoch 31/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0014
# Epoch 32/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0013
# Epoch 33/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0014
# Epoch 34/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0013
# Epoch 35/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0013
# Epoch 36/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0012
# Epoch 37/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0012
# Epoch 38/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0012
# Epoch 39/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0012
# Epoch 40/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0012
# Epoch 41/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0012
# Epoch 42/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0011
# Epoch 43/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0012
# Epoch 44/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0012
# Epoch 45/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0012
# Epoch 46/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0011
# Epoch 47/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0011
# Epoch 48/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0011
# Epoch 49/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0011
# Epoch 50/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0010

# %%
# Teraz przygotujemy zestaw testowy w podobny sposób, jak zestaw treningowy.
# Poniższe czynności zostały wykonane tak,
# aby pierwsze 60 elementów zestawu testowego miało 60 poprzednich wartości
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

# %%
# Przygotowanie X_testu i predykcja cen akcji
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step

# %%
# Wizualizacja wyników dla sieci LSTM
plot_predictions(test_set,predicted_stock_price)

# %%
# Ocena modelu
return_rmse(test_set,predicted_stock_price)
return_mae(test_set,predicted_stock_price)
# Out:
# ------------------------------
# Błąd średniokwadratowy modelu 2.48.
# ------------------------------
# Średni błąd bezwzględny: 1.57.
# Średni błąd bezwzględny procentowy: 0.99%
# ------------------------------

# %%
# Architektura z bramką GRU
regressorGRU = Sequential()
# Warstwa wejściowa
regressorGRU.add(Input(shape=(X_train.shape[1], 1)))
# Pierwsza warstwa GRU z regularyzacją Dropout
regressorGRU.add(GRU(units=50, return_sequences=True, activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Druga warstwa GRU z regularyzacją Dropout
regressorGRU.add(GRU(units=50, return_sequences=True, activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Trzecia warstwa GRU z regularyzacją Dropout
regressorGRU.add(GRU(units=50, return_sequences=True, activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Czwarta warstwa GRU z regularyzacją Dropout
regressorGRU.add(GRU(units=50, activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Warstwa wyjściowa
regressorGRU.add(Dense(units=1))

# Ustawiamy funkcję optymalizującą wagi (uczącą) i funkcję straty
regressorGRU.compile(optimizer='rmsprop', loss='mean_squared_error')

# Trenujemy sieć, ustawiamy ilość epok i ilość podawanych próbek ze zbioru trenującego
# wersja bez Early Stopping
#regressorGRU.fit(X_train,y_train,epochs=50,batch_size=32)

# Wersja treningu z mechanizmem Early Stopping zapobiegającym przeuczeniu się sieci
# (zakomentować powyższe, odkomentować poniższe)
early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
regressorGRU.fit(X_train, y_train, epochs=100, batch_size=32, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0158
# Epoch 2/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0084
# Epoch 3/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0071
# Epoch 4/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0061
# Epoch 5/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0053
# Epoch 6/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0049
# Epoch 7/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0043
# Epoch 8/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0040
# Epoch 9/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0039
# Epoch 10/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0036
# Epoch 11/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0036
# Epoch 12/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0033
# Epoch 13/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0032
# Epoch 14/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0032
# Epoch 15/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0033
# Epoch 16/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0030
# Epoch 17/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0028
# Epoch 18/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029
# Epoch 19/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0026
# Epoch 20/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0028
# Epoch 21/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026
# Epoch 22/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025
# Epoch 23/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024
# Epoch 24/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024
# Epoch 25/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024
# Epoch 26/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025
# Epoch 27/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024
# Epoch 28/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0023
# Epoch 29/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0023
# Epoch 30/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022
# Epoch 31/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022
# Epoch 32/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0022
# Epoch 33/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0022
# Epoch 34/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0021
# Epoch 35/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0020
# Epoch 36/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0021
# Epoch 37/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0020
# Epoch 38/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019
# Epoch 39/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019
# Epoch 40/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018
# Epoch 41/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018
# Epoch 42/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019
# Epoch 43/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018
# Epoch 44/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0018
# Epoch 45/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0017
# Epoch 46/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017
# Epoch 47/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017
# Epoch 48/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016
# Epoch 49/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017
# Epoch 50/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0017
# Epoch 51/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0015
# Epoch 52/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0017
# Epoch 53/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0016
# Epoch 54/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016
# Epoch 55/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016
# Epoch 56/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016

# %%
# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
GRU_predicted_stock_price = regressorGRU.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step

# %%
# Wizualizacja wyników dla sieci GRU
plot_predictions(test_set,GRU_predicted_stock_price)

# %%
# Ocena modelu
return_rmse(test_set,GRU_predicted_stock_price)
return_mae(test_set,GRU_predicted_stock_price)
# Out:
# ------------------------------
# Błąd średniokwadratowy modelu 2.38.
# ------------------------------
# Średni błąd bezwzględny: 1.55.
# Średni błąd bezwzględny procentowy: 0.97%
# ------------------------------
